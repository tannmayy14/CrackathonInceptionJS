# %%
# !pip install ultralytics -q

# %%
import os
from pathlib import Path
from ultralytics import YOLO
import shutil
import kagglehub

# %%
path = kagglehub.dataset_download("anulayakhare/crackathon-data")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'crackathon-data' dataset.
# Path to dataset files: /kaggle/input/crackathon-data

# %%
dataset_path = os.path.join(path, "randomized_dataset")
test_images_path = Path(dataset_path) / "test" / "images"  # Adjust based on actual structure
weights_path = "best.pt"
print(f"Test images location: {test_images_path}")
print(f"Weights: {weights_path}")
# Out:
# Test images location: /kaggle/input/crackathon-data/randomized_dataset/test/images
# Weights: best.pt

# %%
model = YOLO(weights_path)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
# Create empty txt files for images with no detections
test_images = list(test_images_path.glob("*.jpg"))
labels_path = Path("InceptionJS/predictions/labels/")

for img_path in test_images:
    txt_file = labels_path / f"{img_path.stem}.txt"
    if not txt_file.exists():
        # Create empty file
        txt_file.touch()

print(f"✓ Ensured all {len(test_images)} images have .txt files")
# Out:
# ✓ Ensured all 6000 images have .txt files

# %%
results = model.predict(
    source=test_images_path,
    save_txt=True,
    save_conf=True,
    conf=0.1,
    iou=0.55,
    project="InceptionJS",
    name="predictions",
    stream=True,
    exist_ok=True
)
for result in results:
  pass

print(f"✓ Inference complete!")
print(f"✓ Predictions saved to: InceptionJS/predictions/labels/")

# Cell 5: Move predictions to submission folder
labels_path = Path("InceptionJS/predictions/labels/")
output_dir = Path("predictions")
# Out:
# Streaming output truncated to the last 5000 lines.
# image 1006/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006481.jpg: 768x768 1 Longitudinal_Crack, 1 Alligator_Crack, 37.3ms
# image 1007/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006483.jpg: 768x768 2 Other_Corruptions, 38.3ms
# image 1008/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006486.jpg: 768x768 1 Longitudinal_Crack, 1 Transverse_Crack, 37.6ms
# image 1009/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006487.jpg: 768x768 1 Longitudinal_Crack, 37.1ms
# image 1010/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006499.jpg: 768x768 2 Transverse_Cracks, 1 Alligator_Crack, 1 Other_Corruption, 37.8ms
# image 1011/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006500.jpg: 768x768 1 Longitudinal_Crack, 2 Transverse_Cracks, 37.4ms
# image 1012/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006507.jpg: 768x768 1 Other_Corruption, 37.0ms
# image 1013/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006510.jpg: 768x768 (no detections), 36.0ms
# image 1014/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006520.jpg: 416x768 (no detections), 20.0ms
# image 1015/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006531.jpg: 768x768 2 Other_Corruptions, 36.2ms
# image 1016/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006536.jpg: 768x768 1 Longitudinal_Crack, 36.9ms
# image 1017/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006549.jpg: 768x768 3 Other_Corruptions, 37.3ms
# image 1018/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006550.jpg: 768x768 2 Alligator_Cracks, 2 Potholes, 37.0ms
# image 1019/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006559.jpg: 768x768 4 Alligator_Cracks, 4 Other_Corruptions, 4 Potholes, 36.5ms
# image 1020/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006562.jpg: 768x768 1 Transverse_Crack, 1 Pothole, 35.9ms
# image 1021/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006563.jpg: 768x768 (no detections), 37.5ms
# image 1022/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006566.jpg: 768x768 7 Potholes, 36.1ms
# image 1023/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006573.jpg: 768x768 1 Alligator_Crack, 37.2ms
# image 1024/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006585.jpg: 768x768 1 Alligator_Crack, 3 Potholes, 38.0ms
# image 1025/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006589.jpg: 448x768 (no detections), 23.2ms
# image 1026/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/006592.jpg: 416x768 (no detections), 21.2ms
# image 1027/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/
6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038304.jpg: 768x768 1 Other_Corruption, 37.4ms
# image 5984/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038313.jpg: 768x768 (no detections), 36.2ms
# image 5985/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038318.jpg: 768x768 1 Alligator_Crack, 1 Other_Corruption, 36.9ms
# image 5986/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038319.jpg: 768x768 1 Longitudinal_Crack, 1 Pothole, 37.6ms
# image 5987/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038326.jpg: 768x768 2 Longitudinal_Cracks, 2 Transverse_Cracks, 37.0ms
# image 5988/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038327.jpg: 768x768 (no detections), 37.3ms
# image 5989/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038329.jpg: 768x768 2 Longitudinal_Cracks, 37.6ms
# image 5990/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038333.jpg: 416x768 (no detections), 20.5ms
# image 5991/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038338.jpg: 448x768 1 Longitudinal_Crack, 21.5ms
# image 5992/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038346.jpg: 768x768 1 Longitudinal_Crack, 2 Other_Corruptions, 36.0ms
# image 5993/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038347.jpg: 768x768 1 Longitudinal_Crack, 1 Transverse_Crack, 37.6ms
# image 5994/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038348.jpg: 768x768 1 Alligator_Crack, 2 Other_Corruptions, 37.1ms
# image 5995/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038351.jpg: 416x768 (no detections), 20.2ms
# image 5996/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038353.jpg: 768x768 1 Longitudinal_Crack, 2 Alligator_Cracks, 1 Other_Corruption, 36.2ms
# image 5997/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038355.jpg: 768x768 1 Longitudinal_Crack, 2 Alligator_Cracks, 2 Potholes, 36.1ms
# image 5998/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038368.jpg: 448x768 1 Transverse_Crack, 23.8ms
# image 5999/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038369.jpg: 768x768 2 Longitudinal_Cracks, 8 Transverse_Cracks, 1 Alligator_Crack, 36.2ms
# image 6000/6000 /kaggle/input/crackathon-data/randomized_dataset/test/images/038385.jpg: 768x768 1 Transverse_Crack, 36.4ms
# Speed: 4.0ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 768, 768)
# Results saved to /content/InceptionJS/predictions
# 6000 labels saved to /content/InceptionJS/predictions/labels
# ✓ Inference complete!
# ✓ Predictions saved to: InceptionJS/predictions/labels/

# %%
# Cell 6: Sanity Check
print("\n" + "="*50)
print("SANITY CHECK")
print("="*50)

test_images = list(test_images_path.glob("*.jpg")) + list(test_images_path.glob("*.png"))
pred_files = list(labels_path.glob("*.txt"))

# Check number of files
print(f"\n1. Number of prediction files: {len(pred_files)}")
print(f"   Number of test images: {len(test_images)}")
print(f"   Match: {'YES' if len(pred_files) == len(test_images) else 'NO'}")

# Check file naming convention
print(f"\n2. File naming convention check:")
mismatched = []
for img_path in test_images:
    pred_file = labels_path / f"{img_path.stem}.txt"
    if not pred_file.exists():
        mismatched.append(img_path.name)

if mismatched:
    print(f"   ✗ Missing predictions for {len(mismatched)} images: {mismatched[:5]}")
else:
    print(f"   ✓ All test images have corresponding .txt files")

# Check format of predictions
print(f"\n3. Format validation (sample 5 files):")
non_empty_files = [f for f in pred_files if f.stat().st_size > 0]
for pred_file in non_empty_files[:5]:
    print(f"\n   File: {pred_file.name}")
    with open(pred_file, 'r') as f:
        lines = f.readlines()
        for i, line in enumerate(lines[:3]):  # Show first 3 lines
            parts = line.strip().split()
            if len(parts) == 6:
                cls, x, y, w, h, conf = parts
                print(f"      Line {i+1}: class={cls}, x={x}, y={y}, w={w}, h={h}, conf={conf}")
                # Validate class is 0-4
                try:
                    if int(cls) not in range(5):
                        print(f"WARNING: Invalid class ID")
                except:
                    print(f"WARNING: Invalid class value")
            else:
                print(f"WARNING: Line {i+1} has {len(parts)} values (expected 6)")

# Check class distribution
print(f"\n4. Class distribution in predictions:")
class_counts = {0: 0, 1: 0, 2: 0, 3: 0, 4: 0}
class_names = {0: "Longitudinal", 1: "Transverse", 2: "Alligator", 3: "Other", 4: "Pothole"}
total_detections = 0
empty_files = 0

for pred_file in pred_files:
    with open(pred_file, 'r') as f:
        lines = f.readlines()
        if len(lines) == 0:
            empty_files += 1
        for line in lines:
            try:
                parts = line.strip().split()
                if len(parts) >= 1:
                    cls = int(parts[0])
                    if cls in class_counts:
                        class_counts[cls] += 1
                        total_detections += 1
            except:
                pass

for cls_id, count in class_counts.items():
    print(f"   Class {cls_id} ({class_names[cls_id]}): {count} detections")
print(f"   Total detections: {total_detections}")
print(f"   Empty files (no detections): {empty_files}")

print(f"\n5. Ready for submission:")
print(f"   ✓ Zip the 'predictions' folder and submit")
# Out:
# ==================================================
# SANITY CHECK
# ==================================================
#
# 1. Number of prediction files: 6000
#    Number of test images: 6000
#    Match: ✓ YES
#
# 2. File naming convention check:
#    ✓ All test images have corresponding .txt files
#
# 3. Format validation (sample 5 files):
#
#    File: 006920.txt
#       Line 1: class=3, x=0.657359, y=0.915005, w=0.103371, h=0.0553405, conf=0.768811
#       Line 2: class=3, x=0.388046, y=0.556322, w=0.0970065, h=0.0249637, conf=0.721135
#       Line 3: class=3, x=0.966031, y=0.688207, w=0.0677486, h=0.0409776, conf=0.631939
#
#    File: 038031.txt
#       Line 1: class=3, x=0.901315, y=0.726365, w=0.181104, h=0.0550578, conf=0.704937
#       Line 2: class=3, x=0.806588, y=0.777384, w=0.386749, h=0.167169, conf=0.656239
#       Line 3: class=0, x=0.49181, y=0.875604, w=0.0858617, h=0.191266, conf=0.522971
#
#    File: 024504.txt
#       Line 1: class=2, x=0.391975, y=0.864101, w=0.757348, h=0.269284, conf=0.59839
#       Line 2: class=3, x=0.553627, y=0.923839, w=0.435385, h=0.0971731, conf=0.471807
#       Line 3: class=3, x=0.461433, y=0.730336, w=0.0926452, h=0.17498, conf=0.121421
#
#    File: 003160.txt
#       Line 1: class=0, x=0.448661, y=0.819372, w=0.0847748, h=0.297979, conf=0.724706
#
#    File: 025762.txt
#       Line 1: class=4, x=0.433981, y=0.694906, w=0.106619, h=0.316813, conf=0.911771
#
# 4. Class distribution in predictions:
#    Class 0 (Longitudinal): 5697 detections
#    Class 1 (Transverse): 2696 detections
#    Class 2 (Alligator): 2253 detections
#    Class 3 (Other): 2481 detections
#    Class 4 (Pothole): 1279 detections
#    Total detections: 14406
#    Empty files (no detections): 1584
#
# 5. Ready for submission:
#    ✓ Zip the 'predictions' folder and submit

# %%
from google.colab import files
import shutil

# Create zip first
shutil.make_archive('test_predictions_labels', 'zip', '/content/InceptionJS/predictions/labels')

# Download
files.download('test_predictions_labels.zip')
print("✓ Download started!")
# Out:
# ✓ Download started!
